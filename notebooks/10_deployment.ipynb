# %%
import joblib
import pandas as pd
import numpy as np

# %%
model = joblib.load("../models/final_gradient_boosting.pkl")

model
# Out:
# GradientBoostingRegressor(max_depth=2, n_estimators=300, random_state=42)

# %%
X_train = pd.read_csv("../data/X_train.csv")

X_train.head()
# Out:
#    best_rank  worst_rank   avg_rank  initial_rank  rank_improvement  \
# 0         18          29  25.250000            18                 0
# 1         30          43  35.076923            43                13
# 2         49          49  49.000000            49                 0
# 3         10          50  29.035533            37                27
# 4         49          49  49.000000            49                 0
#
#    rank_range  rank_volatility  avg_daily_rank_change  peak_popularity  \
# 0          11         5.188127               5.000000               66
# 1          13         4.251696               2.416667               64
# 2           0         0.000000               0.000000               92
# 3          40        10.877507               2.331633               82
# 4           0         0.000000               0.000000               64
#
#    avg_popularity  popularity_gap  playlist_entries  days_to_peak  \
# ...

# %%
X_train.columns
# Out:
# Index(['best_rank', 'worst_rank', 'avg_rank', 'initial_rank',
#        'rank_improvement', 'rank_range', 'rank_volatility',
#        'avg_daily_rank_change', 'peak_popularity', 'avg_popularity',
#        'popularity_gap', 'playlist_entries', 'days_to_peak',
#        'stability_score'],
#       dtype='str')

# %%
sample = pd.DataFrame({
    "best_rank":[5],
    "worst_rank":[30],
    "avg_rank":[15],
    "initial_rank":[20],
    "rank_improvement":[15],
    "rank_range":[25],
    "rank_volatility":[6.2],
    "avg_daily_rank_change":[1.8],
    "peak_popularity":[90],
    "avg_popularity":[82],
    "popularity_gap":[8],
    "playlist_entries":[65],
    "days_to_peak":[18],
    "stability_score":[74]
})

sample
# Out:
#    best_rank  worst_rank  avg_rank  initial_rank  rank_improvement  \
# 0          5          30        15            20                15
#
#    rank_range  rank_volatility  avg_daily_rank_change  peak_popularity  \
# 0          25              6.2                    1.8               90
#
#    avg_popularity  popularity_gap  playlist_entries  days_to_peak  \
# 0              82               8                65            18
#
#    stability_score
# 0               74

# %%
prediction = model.predict(sample)

prediction
# Out:
# array([252.01577552])

# %%
print(
    f"Predicted Playlist Survival: {prediction[0]:.1f} days"
)
# Out:
# Predicted Playlist Survival: 252.0 days

# %%
samples = pd.DataFrame({

    "best_rank":[1,8,20],

    "worst_rank":[15,30,45],

    "avg_rank":[7,18,30],

    "initial_rank":[12,20,40],

    "rank_improvement":[11,12,20],

    "rank_range":[14,22,25],

    "rank_volatility":[3.5,7.2,12.4],

    "avg_daily_rank_change":[0.8,1.9,3.4],

    "peak_popularity":[96,84,70],

    "avg_popularity":[91,79,66],

    "popularity_gap":[5,5,4],

    "playlist_entries":[110,55,20],

    "days_to_peak":[8,20,45],

    "stability_score":[120,62,18]

})

samples
# Out:
#    best_rank  worst_rank  avg_rank  initial_rank  rank_improvement  \
# 0          1          15         7            12                11
# 1          8          30        18            20                12
# 2         20          45        30            40                20
#
#    rank_range  rank_volatility  avg_daily_rank_change  peak_popularity  \
# 0          14              3.5                    0.8               96
# 1          22              7.2                    1.9               84
# 2          25             12.4                    3.4               70
#
#    avg_popularity  popularity_gap  playlist_entries  days_to_peak  \
# 0              91               5               110             8
# 1              79               5                55            20
# 2              66               4                20            45
#
#    stability_score
# 0              120
# 1               62
# 2               18

# %%
predictions = model.predict(samples)

samples["Predicted Days"] = predictions

samples
# Out:
#    best_rank  worst_rank  avg_rank  initial_rank  rank_improvement  \
# 0          1          15         7            12                11
# 1          8          30        18            20                12
# 2         20          45        30            40                20
#
#    rank_range  rank_volatility  avg_daily_rank_change  peak_popularity  \
# 0          14              3.5                    0.8               96
# 1          22              7.2                    1.9               84
# 2          25             12.4                    3.4               70
#
#    avg_popularity  popularity_gap  playlist_entries  days_to_peak  \
# 0              91               5               110             8
# 1              79               5                55            20
# 2              66               4                20            45
#
#    stability_score  Predicted Days
# 0              120      203.455090
# 1               62      196.099351
# ...

# %%
samples.to_csv(
    "../data/demo_predictions.csv",
    index=False
)

# %% [markdown]
# # Model Deployment
#
# The trained Gradient Boosting model was successfully loaded and used to predict playlist survival for new songs.
#
# Deployment Workflow
#
# - Load trained model
# - Accept song features
# - Generate predictions
# - Return estimated playlist survival
#
# This notebook validates that the saved model can be reused without retraining and is ready to be integrated into a Streamlit web application.
